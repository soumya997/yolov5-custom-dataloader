# %% [markdown]
# # Notebook: V3:
# ### About:
# This is the notebook where I show the without label custom dataloader with augmentations feature enabled. This is the final notebook.
# - the data loader uses only the image folder, no annotation .txt files required
# - It uess template matching for extracting the fingerprints, and creating the bbox labels
# - It has augmentation features enebled.
# - The code for this is provided in the `CustomDataset` class at `utils/only_img_custom_aug_dataloader.py` file.
# - The template image used for template matching can be changed via argparse, `--template` flag.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import torch
import cv2
import matplotlib.pyplot as plt
import glob
from tqdm import tqdm
from utils.only_img_custom_aug_dataloader import create_dataloader
from utils.only_img_custom_aug_dataloader import CustomDataset

# %%
def get_img_cropped(center_x, center_y, width, height, img):         
    x1 = int(center_x - width // 2)
    y1 = int(center_y - height // 2)
    
    x2 = int(x1 + width)
    y2 = int(y1 + height)

    cropped_image = img[y1:y2, x1:x2]
    return cropped_image

# %%
template_file= "/home/somusan/somusan/soumyadip/interview/lens_assignment/yolov5-custom-dataloader/1_3_crop.tif"
dataset = CustomDataset("../images/train/",img_size=1024,batch_size=2, template_file=template_file)
custom_data = dataset[3]
print(custom_data)
# Out:
# (tensor([[[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), tensor([[0.00000, 0.00000, 0.83594, 0.20215, 0.09766, 0.09766],
#         [0.00000, 0.00000, 0.79102, 0.30957, 0.09766, 0.09766]]), '../images/train/6_1.tif', ((1024, 1024), ((1.0, 1.0), (0.0, 0.0))))

# %% [markdown]
# ### Visualize the Output of the Dataloader in Different Image Sizes:

# %%
dataset = CustomDataset("../images/train/",
                        img_size=1024,batch_size=2, 
                        template_file=template_file)
custom_data = dataset[3]
img_viz = custom_data[0].permute(1,2,0).numpy().astype(np.uint8).copy()
for i in range(custom_data[1].shape[0]):
    center_x, center_y, width, height  = custom_data[1][:,2:][i].numpy()*1024

    x1 = int(center_x - width / 2)
    y1 = int(center_y - height / 2)

    x2 = int(center_x + width / 2)
    y2 = int(center_y + height / 2)

    color = (0, 255, 0)  
    thickness = 2  

    print((x1, y1), (x2, y2))

    cv2.rectangle(img_viz, (x1, y1), (x2, y2), color, thickness)

plt.imshow(img_viz)
# Out:
# (44, 552) (144, 652)
# (453, 72) (553, 172)

# %%
dataset = CustomDataset("../images/train/",
                        img_size=640,batch_size=2,
                        template_file=template_file)
custom_data = dataset[3]
img_viz = custom_data[0].permute(1,2,0).numpy().astype(np.uint8).copy()
for i in range(custom_data[1].shape[0]):
    center_x, center_y, width, height  = custom_data[1][:,2:][i].numpy()*640

    x1 = int(center_x - width / 2)
    y1 = int(center_y - height / 2)

    x2 = int(center_x + width / 2)
    y2 = int(center_y + height / 2)

    color = (0, 255, 0)  
    thickness = 2  

    print((x1, y1), (x2, y2))

    cv2.rectangle(img_viz, (x1, y1), (x2, y2), color, thickness)

plt.imshow(img_viz)
# Out:
# (400, 116) (500, 216)
# (381, 501) (481, 601)

# %%
center_x1, center_y1, width1, height1  = custom_data[1][:,2:][0].numpy()*640
center_x2, center_y2, width2, height2  = custom_data[1][:,2:][1].numpy()*640


image1 =get_img_cropped(center_x1, center_y1, width1, height1 , img_viz)
image2 =get_img_cropped(center_x2, center_y2, width2, height2 , img_viz)


plt.subplot(1,3,1)
plt.imshow(image1)

plt.subplot(1,3,2)
plt.imshow(image2)

plt.subplot(1,3,3)
plt.imshow(img_viz)

# %% [markdown]
# ### Before Training Instruction:
# - Before starting the training process, from the `train.py` file use `create_dataloader` from `utils/only_img_custom_aug_dataloader.py` by importing like this `from utils.only_img_custom_aug_dataloader import create_dataloader`.

# %%
IMG_SIZE = 640
BATCH_SIZE = 2
EPOCHS = 3

# %%
# !python train.py --img {IMG_SIZE} \
                 --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data ../images/fingerprint_label.yaml \
                 --weights yolov5s.pt \
                 --hyp data/hyps/hyp.scratch-low.yaml \
                 --project custom-dataloader-w-aug \
                 --template {template_file}
# Out:
# train: weights=yolov5s.pt, cfg=, data=../images/fingerprint_label.yaml, hyp=data/hyps/hyp.scratch-low.yaml, template=/home/somusan/somusan/soumyadip/interview/lens_assignment/yolov5-custom-dataloader/1_3_crop.tif, epochs=3, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=custom-dataloader-w-aug, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-8-8 Python-3.9.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, template=/home/somusan/somusan/soumyadip/interview/lens_assignment/yolov5-custom-dataloader/1_3_crop.tif
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir custom-dataloader-w-aug', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# AutoAnchor: 3.01 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to custom-dataloader-w-aug/exp6/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to custom-dataloader-w-aug/exp6
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/2     0.644G    0.07148    0.03062          0          2        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        100        200      0.487      0.945      0.537      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/2     0.644G    0.05045    0.02046          0          2        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        100        200      0.909      0.905      0.953      0.326
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         2/2     0.646G    0.04266     0.0173          0          2        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        100        200      0.746      0.895      0.862      0.546
#
# 3 epochs completed in 0.013 hours.
# Optimizer stripped from custom-dataloader-w-aug/exp6/weights/last.pt, 14.4MB
# Optimizer stripped from custom-dataloader-w-aug/exp6/weights/best.pt, 14.4MB
#
# Validating custom-dataloader-w-aug/exp6/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        100        200      0.754       0.93      0.875      0.548
# Results saved to custom-dataloader-w-aug/exp6
